# %%
import os
from google.colab import drive
drive.mount('/content/drive')
 
path = "/content/drive/MyDrive/Public CS 689 Project/loss-landscape-20201130T195424Z-001.zip (Unzipped Files)/loss-landscape"
os.chdir(path)
print(os.getcwd())
# !nvidia-smi
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Public CS 689 Project/loss-landscape-20201130T195424Z-001.zip (Unzipped Files)/loss-landscape
# Wed Dec  2 12:02:00 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# ...

# %%
# Install haste library
# !pip install haste/haste_*.whl
# Out:
# Processing ./haste/haste_pytorch-0.5.0rc0-cp36-cp36m-linux_x86_64.whl
# Processing /content/drive/MyDrive/Public CS 689 Project/loss-landscape-20201130T195424Z-001.zip (Unzipped Files)/loss-landscape/haste/haste_tf-0.5.0rc0-cp36-cp36m-linux_x86_64.whl
# ...

# %%
# Visualize the haste sentiment model
# !python Visualize_sentiment_haste.py --model_file=gru_sentiment_haste_d0.1_z0_h256.pt --visualize_file_suffix=haste_d0.1_z0_h256
# Out:
# Streaming output truncated to the last 5000 lines.
# Evaluating coordinate 94/2601.
# Time elapsed = 1280 sec.
# Evaluating coordinate 95/2601.
# Time elapsed = 1294 sec.
# Evaluating coordinate 96/2601.
# Time elapsed = 1307 sec.
# Evaluating coordinate 97/2601.
# Time elapsed = 1321 sec.
# Evaluating coordinate 98/2601.
# Time elapsed = 1334 sec.
# Evaluating coordinate 99/2601.
# Time elapsed = 1348 sec.
# Evaluating coordinate 100/2601.
# Time elapsed = 1361 sec.
# Evaluating coordinate 101/2601.
# Time elapsed = 1375 sec.
# Evaluating coordinate 102/2601.
# Time elapsed = 1389 sec.
# Evaluating coordinate 103/2601.
# Time elapsed = 1402 sec.
# Evaluating coordinate 104/2601.
# Time elapsed = 1416 sec.
# Evaluating coordinate 105/2601.
# Time elapsed = 1429 sec.
# Evaluating coordinate 106/2601.
# Time elapsed = 1443 sec.
# Evaluating coordinate 107/2601.
# Time elapsed = 1456 sec.
# Evaluating coordinate 108/2601.
# Time elapsed = 1470 sec.
# Evaluating coordinate 109/2601.
# ...

# %%
# Visualize the haste sentiment model
# !python Visualize_sentiment_haste.py --model_file=gru_sentiment_haste_d0.1_z0_h256.pt --visualize_file_suffix=haste_d0.1_z0_h256
# Out:
# device =  cuda
# model file passed = gru_sentiment_haste_d0.1_z0_h256.pt
# File sentiment_models/gru_sentiment_direction_file_haste_d0.1_z0_h256.h5 already exists with directions.
# File sentiment_models/gru_sentiment_surface_file_haste_d0.1_z0_h256.h5 already exists with coordinates.
# Cosine similarity between X and Y axis is -0.0001571.
# cuda
# Creating tabular data.
# Time to create tabular data: 75 sec.
# Building vocabulary from glove embeddings.
# Finished crunch. Total time = 0 seconds.
# Print the plot
# ------------------------------------------------------------------
# plot_2d_contour
# ------------------------------------------------------------------
# loading surface file: sentiment_models/gru_sentiment_surface_file_haste_d0.1_z0_h256.h5
# len(xcoordinates): 51   len(ycoordinates): 51
# max(train_loss) = 2.327680 	 min(train_loss) = 0.001986
# [[1.27228551 1.23284547 1.17820746 ... 0.59957115 0.6599622  0.73408173]
# ...

# %%
# !python Sentiment_haste.py --model_file=gru_sentiment_haste_again_d0_z0.pt
# Out:
# model file passed = gru_sentiment_haste_again_d0_z0.pt
# tune dropconnect = False
# cuda
# Creating tabular data.
# Time to create tabular data: 79 sec.
# Building vocabulary from glove embeddings.
# Model loaded from file sentiment_models/gru_sentiment_haste_again_d0_z0.pt.
# Test Loss: 0.572 | Test Acc: 87.40%
