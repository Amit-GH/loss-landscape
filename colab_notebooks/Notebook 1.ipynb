# %%
import os
from google.colab import drive
drive.mount('/content/drive')
 
path = "/content/drive/MyDrive/Public CS 689 Project/loss-landscape-20201130T195424Z-001.zip (Unzipped Files)/loss-landscape"
os.chdir(path)
print(os.getcwd())
# !nvidia-smi
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Public CS 689 Project/loss-landscape-20201130T195424Z-001.zip (Unzipped Files)/loss-landscape
# Fri Dec 18 22:36:28 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    22W / 300W |      0MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# ...

# %%
# !pip install haste/haste_*.whl
# Out:
# Processing ./haste/haste_pytorch-0.5.0rc0-cp36-cp36m-linux_x86_64.whl
# Processing /content/drive/MyDrive/Public CS 689 Project/loss-landscape-20201130T195424Z-001.zip (Unzipped Files)/loss-landscape/haste/haste_tf-0.5.0rc0-cp36-cp36m-linux_x86_64.whl
# ...

# %%
# Learn and save the model
# Note: If you manually delete the saved model and create a new model with new layer parameters,
# then you also need to delete the direction file in sentiment_models directory.

# parameters used: d=0, z=0.1, lr=0.001, epochs=6
# Learning the model again to see if there are any changes in the visualizations.
import torch
torch.manual_seed(123)

# !python Sentiment_haste.py --model_file=gru_sentiment_haste_again_d0_z0.1.pt
# Out:
# model file passed = gru_sentiment_haste_again_d0_z0.1.pt
# tune dropconnect = False
# cuda
# Creating tabular data.
# Time to create tabular data: 81 sec.
# Building vocabulary from glove embeddings.
# Model loaded from file sentiment_models/gru_sentiment_haste_again_d0_z0.1.pt.
# Test Loss: 0.738 | Test Acc: 88.39%

# %%
# Learn and save the model
# Note: If you manually delete the saved model and create a new model with new layer parameters,
# then you also need to delete the direction file in sentiment_models directory.

# parameters used: d=0, z=0.1, lr=0.001, epochs=6
# Learning the model again to see if there are any changes in the visualizations.
# import torch
# torch.manual_seed(123)

# !python Sentiment_haste.py --model_file=gru_sentiment_haste_again_d0_z0.1.pt
# Out:
# model file passed = gru_sentiment_haste_again_d0_z0.1.pt
# tune dropconnect = False
# cuda
# Creating tabular data.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/torchtext/data/dataset.py", line 271, in __init__
#     examples = [make_example(line, fields) for line in reader]
#   File "/usr/local/lib/python3.6/dist-packages/torchtext/data/dataset.py", line 271, in <listcomp>
#     examples = [make_example(line, fields) for line in reader]
#   File "/usr/local/lib/python3.6/dist-packages/torchtext/data/example.py", line 34, in fromCSV
#     return cls.fromlist(data, fields)
#   File "/usr/local/lib/python3.6/dist-packages/torchtext/data/example.py", line 52, in fromlist
#     setattr(ex, name, field.preprocess(val))
#   File "/usr/local/lib/python3.6/dist-packages/torchtext/data/field.py", line 179, in preprocess
#     x = self.tokenize(x.rstrip('\n'))
# ...

# %%
# Visualize the haste sentiment model
# !python Visualize_sentiment_haste.py --model_file=gru_sentiment_haste_again_d0_z0.1.pt --visualize_file_suffix=haste_d0_z0.1_again
# Out:
# Traceback (most recent call last):
#   File "Visualize_sentiment_haste.py", line 8, in <module>
#     import net_plotter
#   File "/content/drive/My Drive/Public CS 689 Project/loss-landscape-20201130T195424Z-001.zip (Unzipped Files)/loss-landscape/net_plotter.py", line 10, in <module>
#     import model_loader
#   File "/content/drive/My Drive/Public CS 689 Project/loss-landscape-20201130T195424Z-001.zip (Unzipped Files)/loss-landscape/model_loader.py", line 2, in <module>
#     import cifar10.model_loader
#   File "/content/drive/My Drive/Public CS 689 Project/loss-landscape-20201130T195424Z-001.zip (Unzipped Files)/loss-landscape/cifar10/model_loader.py", line 4, in <module>
#     import cifar10.models.resnet as resnet
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
# ...

# %%
# parameters used: d=0, z=0, lr=0.001, epochs=10, h=128
# Learning the model again to see if there are any changes in the visualizations.
import torch
torch.manual_seed(12)

# !python Sentiment_haste.py --model_file=gru_sentiment_haste_again_d0_z0.pt
# Out:
# model file passed = gru_sentiment_haste_again_d0_z0.pt
# tune dropconnect = False
# cuda
# Creating tabular data.
# Time to create tabular data: 83 sec.
# Building vocabulary from glove embeddings.
# Learning model with fixed params. hidden_dim 128 dropout 0 zoneout 0.
# Learning the model.
# Epoch: 01 | Epoch Time: 0m 30s
# 	Train Loss: 0.693 | Train Acc: 50.08%
# 	 Val. Loss: 0.680 |  Val. Acc: 55.91%
# Validation data c_matrix = [3231 2510 3002 3757], precision = 0.5995, recall = 0.5559, f1 = 0.5768.
# Model saved after epoch 1.
# Epoch: 02 | Epoch Time: 0m 30s
# 	Train Loss: 0.691 | Train Acc: 50.57%
# 	 Val. Loss: 0.613 |  Val. Acc: 68.38%
# Validation data c_matrix = [4094 1813 2139 4454], precision = 0.7107, recall = 0.6756, f1 = 0.6927.
# Model saved after epoch 2.
# Epoch: 03 | Epoch Time: 0m 30s
# 	Train Loss: 0.507 | Train Acc: 70.59%
# 	 Val. Loss: 0.350 |  Val. Acc: 85.26%
# ...

# %%
# Visualize the haste sentiment model
# !python Visualize_sentiment_haste.py --model_file=gru_sentiment_haste_again_d0_z0.pt --visualize_file_suffix=haste_d0_z0_again
# Out:
# Streaming output truncated to the last 5000 lines.
# Evaluating coordinate 111/2601.
# Time elapsed = 1425 sec.
# Evaluating coordinate 112/2601.
# Time elapsed = 1438 sec.
# Evaluating coordinate 113/2601.
# Time elapsed = 1451 sec.
# Evaluating coordinate 114/2601.
# Time elapsed = 1463 sec.
# Evaluating coordinate 115/2601.
# Time elapsed = 1476 sec.
# Evaluating coordinate 116/2601.
# Time elapsed = 1489 sec.
# Evaluating coordinate 117/2601.
# Time elapsed = 1502 sec.
# Evaluating coordinate 118/2601.
# Time elapsed = 1514 sec.
# Evaluating coordinate 119/2601.
# Time elapsed = 1527 sec.
# Evaluating coordinate 120/2601.
# Time elapsed = 1540 sec.
# Evaluating coordinate 121/2601.
# Time elapsed = 1553 sec.
# Evaluating coordinate 122/2601.
# Time elapsed = 1565 sec.
# Evaluating coordinate 123/2601.
# Time elapsed = 1578 sec.
# Evaluating coordinate 124/2601.
# Time elapsed = 1591 sec.
# Evaluating coordinate 125/2601.
# Time elapsed = 1604 sec.
# ...
